# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Marcos de datos

# %%
data = [
    ['Nisan', 'Stanza', 1991, 138, 4, 'MANUAL', 'sedan', 2000],
    ['Hyundai', 'Sonata', 2017, None, 4, 'AUTOMATIC', 'Sedan', 27150],
    ['Lotus', 'Elise', 2010, 218, 4, 'MANUAL', 'convertible', 54990],
    ['GMC', 'Acadia', 2017, 194, 4, 'AUTOMATIC', '4dr SUV', 34450],
    ['Nissan', 'Frontier', 2017, 261, 6, 'MANUAL', 'Pickup', 32340],
]

columns = [
    'Make', 'Model', 'Year', 'Engine HP', 'Engine Cylinders', 'Transmission Type', 'Vehicle_Style', 'MSRP'
]

# %%
df = pd.DataFrame(data, columns=columns)
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0    Nisan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
data = [
    {
        'Make': 'Nisan',   
        'Model': 'Stanza',   
        'Year': 1991, 
        'Engine HP': 138,  
        'Engine Cylinders': 4, 
        'Transmission Type': 'MANUAL',    
        'Vehicle Style': 'sedan',       
        'MSRP': 2000
    },
    {
        'Make': 'Hyundai', 
        'Model': 'Sonata',   
        'Year': 2017, 
        'Engine HP': None, 
        'Engine Cylinders': 4, 
        'Transmission Type': 'AUTOMATIC', 
        'Vehicle Style': 'Sedan',       
        'MSRP': 27150
    },
    {
        'Make': 'Lotus',   
        'Model': 'Elise',    
        'Year': 2010, 'Engine HP': 218,  
        'Engine Cylinders': 4, 
        'Transmission Type': 'MANUAL',    
        'Vehicle Style': 'convertible', 
        'MSRP': 54990
    },
    {
        'Make': 'GMC',     
        'Model': 'Acadia',   
        'Year': 2017, 
        'Engine HP': 194,  
        'Engine Cylinders': 4, 
        'Transmission Type': 'AUTOMATIC', 
        'Vehicle Style': '4dr SUV',     
        'MSRP': 34450
    },
    {
        'Make': 'Nissan',  
        'Model': 'Frontier', 
        'Year': 2017, 
        'Engine HP': 261,  
        'Engine Cylinders': 6, 
        'Transmission Type': 'MANUAL',    
        'Vehicle Style': 'Pickup',      
        'MSRP': 32340
    },
]

# %%
df = pd.DataFrame(data)
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0    Nisan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df.head(n=2)
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0    Nisan  Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
#
#   Vehicle Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150

# %% [markdown]
# Series

# %%
df.Make
# Out:
# 0      Nisan
# 1    Hyundai
# 2      Lotus
# 3        GMC
# 4     Nissan
# Name: Make, dtype: str

# %%
df[['Make', 'Model', 'MSRP']]
# Out:
#       Make     Model   MSRP
# 0    Nisan    Stanza   2000
# 1  Hyundai    Sonata  27150
# 2    Lotus     Elise  54990
# 3      GMC    Acadia  34450
# 4   Nissan  Frontier  32340

# %%
df['id'] = [1, 2, 3, 4, 5]

# %%
df['id'] = [10, 20, 30, 40, 50]

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0    Nisan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle Style   MSRP  id
# 0         sedan   2000  10
# 1         Sedan  27150  20
# 2   convertible  54990  30
# 3       4dr SUV  34450  40
# 4        Pickup  32340  50

# %%
del df['id']

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0    Nisan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %% [markdown]
# Indices

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.Make.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.index = ['a', 'b', 'c', 'd', 'e']

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# a    Nisan    Stanza  1991      138.0                 4            MANUAL
# b  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# c    Lotus     Elise  2010      218.0                 4            MANUAL
# d      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# e   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle Style   MSRP
# a         sedan   2000
# b         Sedan  27150
# c   convertible  54990
# d       4dr SUV  34450
# e        Pickup  32340

# %%
df.loc[['b', 'c']]
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# b  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
# c    Lotus   Elise  2010      218.0                 4            MANUAL
#
#   Vehicle Style   MSRP
# b         Sedan  27150
# c   convertible  54990

# %%
df.iloc[1]
# Out:
# Make                   Hyundai
# Model                   Sonata
# Year                      2017
# Engine HP                  NaN
# Engine Cylinders             4
# Transmission Type    AUTOMATIC
# Vehicle Style            Sedan
# MSRP                     27150
# Name: b, dtype: object

# %%
df = df.reset_index(drop= True)

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0    Nisan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %% [markdown]
# Acceso a elementos

# %% [markdown]
# Operaciones con elementos

# %%
df['Engine HP'] / 100
# Out:
# 0    1.38
# 1     NaN
# 2    2.18
# 3    1.94
# 4    2.61
# Name: Engine HP, dtype: float64

# %%
df['Year'] >= 2015
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# Name: Year, dtype: bool

# %% [markdown]
# Filtros

# %%
df[
    df['Year'] >= 2015
]
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle Style   MSRP
# 1         Sedan  27150
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df[
    (df['Make'] == 'Nissan') & (df['Year'] >= 2015)
]
# Out:
#      Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 4  Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle Style   MSRP
# 4        Pickup  32340

# %% [markdown]
# Operaciones de Cadenas

# %%
'machine learning zoomcamp'.replace(' ', '_')
# Out:
# 'machine_learning_zoomcamp'

# %%
'STRr'.lower()
# Out:
# 'strr'

# %%
df['Vehicle Style'].str.lower()
# Out:
# 0          sedan
# 1          sedan
# 2    convertible
# 3        4dr suv
# 4         pickup
# Name: Vehicle Style, dtype: str

# %% [markdown]
# Resumen

# %%
df.MSRP.describe()
# Out:
# count        5.000000
# mean     30186.000000
# std      18985.044904
# min       2000.000000
# 25%      27150.000000
# 50%      32340.000000
# 75%      34450.000000
# max      54990.000000
# Name: MSRP, dtype: float64

# %% [markdown]
# Valores faltantes

# %%
df.isnull()
# Out:
#     Make  Model   Year  Engine HP  Engine Cylinders  Transmission Type  \
# 0  False  False  False      False             False              False
# 1  False  False  False       True             False              False
# 2  False  False  False      False             False              False
# 3  False  False  False      False             False              False
# 4  False  False  False      False             False              False
#
#    Vehicle Style   MSRP
# 0          False  False
# 1          False  False
# 2          False  False
# 3          False  False
# 4          False  False

# %%
df.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine HP            1
# Engine Cylinders     0
# Transmission Type    0
# Vehicle Style        0
# MSRP                 0
# dtype: int64

# %% [markdown]
# Grupos

# %% [markdown]
# SELECT
#     transmission_type,
#     AVG(MSRP)
# FROM
#     cars
# GROUP BY
#     transmission_type

# %%
df.groupby('Transmission Type').MSRP.mean()
# Out:
# Transmission Type
# AUTOMATIC    30800.000000
# MANUAL       29776.666667
# Name: MSRP, dtype: float64

# %% [markdown]
# Obtener el array de NumPy

# %%
df.MSRP.values
# Out:
# array([ 2000, 27150, 54990, 34450, 32340])

# %%
df.to_dict(orient='records')
# Out:
# [{'Make': 'Nisan',
#   'Model': 'Stanza',
#   'Year': 1991,
#   'Engine HP': 138.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'MANUAL',
#   'Vehicle Style': 'sedan',
#   'MSRP': 2000},
#  {'Make': 'Hyundai',
#   'Model': 'Sonata',
#   'Year': 2017,
#   'Engine HP': nan,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'AUTOMATIC',
#   'Vehicle Style': 'Sedan',
#   'MSRP': 27150},
#  {'Make': 'Lotus',
#   'Model': 'Elise',
#   'Year': 2010,
#   'Engine HP': 218.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'MANUAL',
#   'Vehicle Style': 'convertible',
#   'MSRP': 54990},
#  {'Make': 'GMC',
#   'Model': 'Acadia',
#   'Year': 2017,
#   'Engine HP': 194.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'AUTOMATIC',
#   'Vehicle Style': '4dr SUV',
#   'MSRP': 34450},
#  {'Make': 'Nissan',
#   'Model': 'Frontier',
#   'Year': 2017,
#   'Engine HP': 261.0,
#   'Engine Cylinders': 6,
#   'Transmission Type': 'MANUAL',
#   'Vehicle Style': 'Pickup',
# ...
